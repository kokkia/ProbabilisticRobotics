# %%
from control.matlab import *
from matplotlib import pyplot as plt
    
# 伝達関数のパラメータ
num = [1,1]     # 分子の係数
den = [0.1, 1, 0,0]     # 分母の係数
sys = tf(num, den)  # 伝達関数モデルの作成
bode(sys)           # ボード線図のプロット
print(margin(sys))

plt.show()
# Out:
# (inf, 44.45932734215512, nan, 1.2647443511327583)

# %%
nyquist(sys)
plt.show()
