# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import time
import cvxpy
#from matplotrecorder import matplotrecorder
import kal_python as kal


l_bar = 2.0  # length of bar
M = 1.0  # [kg]
m = 0.3  # [kg]
g = 9.8  # [m/s^2]

Q = np.diag([0.0, 1.0, 1.0, 0.0])
R = np.diag([0.01])
nx = 4
nu = 1   
T = 30  
delta_t = 1

x00 = np.array([
        [0.0],
        [0.0],
        [0.3],
        [0.0]
    ])
x0 = np.array([0,0,0.01,0])

f = kal.inverted_pendulum_cart_function(M,m,l_bar,x0,x0)
sim = kal.simulator(T,delta_t,0,f,x0,False)

sim.draw()
# Out:
# [0.44329847 0.78384186 1.55985134 2.82564295]
